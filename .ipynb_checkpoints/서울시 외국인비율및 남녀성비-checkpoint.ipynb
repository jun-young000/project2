# %%
import pandas as pd
import numpy as np

# %%
# df = pd.read_csv('tidy_2.csv')

# %%
# pd.read_csv('파일경로 + 파일명.csv')
# pd.read_excel('파일경로 + 파일명.xlsx')

# %%
# 서울시 구별 외국인 비율
df=pd.read_csv('Report.csv',encoding='utf-8')
           
df
# Out:
#        기간  자치구         세대          인구       인구.1       인구.2       인구.3  \
# 0      기간  자치구         세대          합계         합계         합계        한국인
# 1      기간  자치구         세대           계         남자         여자          계
# 2    2017   합계  4,220,082  10,124,579  4,957,857  5,166,722  9,857,426
# 3    2017  종로구     73,594     164,257     80,094     84,163    154,770
# 4    2017   중구     60,412     134,593     66,337     68,256    125,709
# ..    ...  ...        ...         ...        ...        ...        ...
# 101  2020  관악구    274,811     509,803    255,211    254,592    495,060
# 102  2020  서초구    173,502     429,025    205,282    223,743    425,126
# 103  2020  강남구    234,872     544,055    260,378    283,677    539,231
# 104  2020  송파구    281,959     673,926    325,080    348,846    667,960
# 105  2020  강동구    196,499     463,998    228,044    235,954    459,970
#
#           인구.4       인구.5     인구.6     인구.7     인구.8  세대당인구   65세이상고령자
# ...

# %%
# 'col1', 'col2' 열 삭제
# df = df.drop(columns=['col1', 'col2'], axis=1)
df=df.drop(columns=['세대', '인구.1',"인구.2","인구.3","인구.4","인구.5","세대당인구","65세이상고령자"], axis=1)
df
# Out:
#        기간  자치구          인구     인구.6     인구.7     인구.8
# 0      기간  자치구          합계    등록외국인    등록외국인    등록외국인
# 1      기간  자치구           계        계       남자       여자
# 2    2017   합계  10,124,579  267,153  127,651  139,502
# 3    2017  종로구     164,257    9,487    4,127    5,360
# 4    2017   중구     134,593    8,884    4,084    4,800
# ..    ...  ...         ...      ...      ...      ...
# 101  2020  관악구     509,803   14,743    6,872    7,871
# 102  2020  서초구     429,025    3,899    1,923    1,976
# 103  2020  강남구     544,055    4,824    2,379    2,445
# 104  2020  송파구     673,926    5,966    2,781    3,185
# 105  2020  강동구     463,998    4,028    1,828    2,200
#
# [106 rows x 6 columns]

# %%
# 컬럼명 변경
df.columns=['년도','지역구','전체인구','등록_외국인','남자_외국인','여자_외국인']

# %%
df
# Out:
#        년도  지역구        전체인구   등록_외국인   남자_외국인   여자_외국인
# 0      기간  자치구          합계    등록외국인    등록외국인    등록외국인
# 1      기간  자치구           계        계       남자       여자
# 2    2017   합계  10,124,579  267,153  127,651  139,502
# 3    2017  종로구     164,257    9,487    4,127    5,360
# 4    2017   중구     134,593    8,884    4,084    4,800
# ..    ...  ...         ...      ...      ...      ...
# 101  2020  관악구     509,803   14,743    6,872    7,871
# 102  2020  서초구     429,025    3,899    1,923    1,976
# 103  2020  강남구     544,055    4,824    2,379    2,445
# 104  2020  송파구     673,926    5,966    2,781    3,185
# 105  2020  강동구     463,998    4,028    1,828    2,200
#
# [106 rows x 6 columns]

# %%
df=df.drop(columns=['남자_외국인','여자_외국인'], axis=1)

# %%
df
# Out:
#        년도  지역구        전체인구   등록_외국인
# 0      기간  자치구          합계    등록외국인
# 1      기간  자치구           계        계
# 2    2017   합계  10,124,579  267,153
# 3    2017  종로구     164,257    9,487
# 4    2017   중구     134,593    8,884
# ..    ...  ...         ...      ...
# 101  2020  관악구     509,803   14,743
# 102  2020  서초구     429,025    3,899
# 103  2020  강남구     544,055    4,824
# 104  2020  송파구     673,926    5,966
# 105  2020  강동구     463,998    4,028
#
# [106 rows x 4 columns]

# %%
#null 값 확인
df.isnull().sum()
# Out:
# 년도        0
# 지역구       0
# 전체인구      0
# 등록_외국인    0
# dtype: int64

# %%
# 인덱스 삭제
df_index=df.drop([0,1])

# %%
df_index
# Out:
#        년도  지역구        전체인구   등록_외국인
# 2    2017   합계  10,124,579  267,153
# 3    2017  종로구     164,257    9,487
# 4    2017   중구     134,593    8,884
# 5    2017  용산구     244,444   15,283
# 6    2017  성동구     312,711    7,903
# ..    ...  ...         ...      ...
# 101  2020  관악구     509,803   14,743
# 102  2020  서초구     429,025    3,899
# 103  2020  강남구     544,055    4,824
# 104  2020  송파구     673,926    5,966
# 105  2020  강동구     463,998    4,028
#
# [104 rows x 4 columns]

# %%
#  멀티 인덱싱  
df_end=df_index.set_index(["년도","지역구"],inplace=False)

# %%
df_end
# Out:
#                 전체인구   등록_외국인
# 년도   지역구
# 2017 합계   10,124,579  267,153
#      종로구     164,257    9,487
#      중구      134,593    8,884
#      용산구     244,444   15,283
#      성동구     312,711    7,903
# ...              ...      ...
# 2020 관악구     509,803   14,743
#      서초구     429,025    3,899
#      강남구     544,055    4,824
#      송파구     673,926    5,966
#      강동구     463,998    4,028
#
# [104 rows x 2 columns]

# %%
df_end.to_csv('df_end.csv')

# %%
# 남녀성비 누계

df1=pd.read_csv('남녀성비_시도_시_군_구__20210913140333_분석(누계).csv',encoding='utf-8')

# %%
df1
# Out:
#     행정구역별(1)  행정구역별(2)               2017             2017.1        2017.2  \
# 0   행정구역별(1)  행정구역별(2)  남녀성비<br>(A÷B×100)  남녀성비<br>(A÷B×100)  남자인구수<br>(A)
# 1   행정구역별(1)  행정구역별(2)               원데이터                 누계          원데이터
# 2      서울특별시        소계               96.1               96.1     4,830,206
# 3        NaN       종로구               96.4               96.4        75,967
# 4        NaN        중구               98.1               98.1        62,253
# 5        NaN       용산구               93.7               93.7       110,878
# 6        NaN       성동구               97.4               97.4       150,368
# 7        NaN       광진구               95.2               95.2       174,414
# 8        NaN      동대문구                100                100       175,324
# 9        NaN       중랑구               99.2               99.2       203,325
# 10       NaN       성북구               95.2               95.2       216,556
# ...

# %%
df2=pd.read_csv('남녀성비_시도_시_군_구__20210913140322_분석(전년_대비_증감률).csv',encoding='utf-8')

# %%
df2
# Out:
#     행정구역별(1)  행정구역별(2)               2017             2017.1        2017.2  \
# 0   행정구역별(1)  행정구역별(2)  남녀성비<br>(A÷B×100)  남녀성비<br>(A÷B×100)  남자인구수<br>(A)
# 1   행정구역별(1)  행정구역별(2)               원데이터          전년 대비 증감률          원데이터
# 2      서울특별시        소계               96.1               -0.4     4,830,206
# 3        NaN       종로구               96.4               -0.6        75,967
# 4        NaN        중구               98.1               -0.6        62,253
# 5        NaN       용산구               93.7               -0.4       110,878
# 6        NaN       성동구               97.4               -0.9       150,368
# 7        NaN       광진구               95.2               -0.6       174,414
# 8        NaN      동대문구              100.0               -0.1       175,324
# 9        NaN       중랑구               99.2               -0.2       203,325
# 10       NaN       성북구               95.2               -0.3       216,556
# ...

# %%
df3=pd.read_csv('남녀성비_시도_시_군_구__20210913140308_분석(전년_대비_증감).csv',encoding='utf-8')

# %%
df3
# Out:
#     행정구역별(1)  행정구역별(2)               2017             2017.1        2017.2  \
# 0   행정구역별(1)  행정구역별(2)  남녀성비<br>(A÷B×100)  남녀성비<br>(A÷B×100)  남자인구수<br>(A)
# 1   행정구역별(1)  행정구역별(2)               원데이터           전년 대비 증감          원데이터
# 2      서울특별시        소계               96.1               -0.4       4830206
# 3      서울특별시       종로구               96.4               -0.6         75967
# 4      서울특별시        중구               98.1               -0.6         62253
# 5      서울특별시       용산구               93.7               -0.4        110878
# 6      서울특별시       성동구               97.4               -0.9        150368
# 7      서울특별시       광진구               95.2               -0.6        174414
# 8      서울특별시      동대문구                100               -0.1        175324
# 9      서울특별시       중랑구               99.2               -0.2        203325
# 10     서울특별시       성북구               95.2               -0.3        216556
# ...

# %%
df4=pd.read_csv('남녀성비_시도_시_군_구.csv',encoding='utf-8')

# %%
df4
# Out:
#     행정구역별(1)  행정구역별(2)               2017        2017.1        2017.2  \
# 0   행정구역별(1)  행정구역별(2)  남녀성비<br>(A÷B×100)  남자인구수<br>(A)  여자인구수<br>(B)
# 1      서울특별시        소계               96.1     4,830,206     5,027,220
# 2        NaN       종로구               96.4        75,967        78,803
# 3        NaN        중구               98.1        62,253        63,456
# 4        NaN       용산구               93.7       110,878       118,283
# 5        NaN       성동구               97.4       150,368       154,440
# 6        NaN       광진구               95.2       174,414       183,289
# 7        NaN      동대문구              100.0       175,324       175,323
# 8        NaN       중랑구               99.2       203,325       204,901
# 9        NaN       성북구               95.2       216,556       227,499
# 10       NaN       강북구               96.0       158,918       165,561
# 11       NaN       도봉구               96.2       168,759       175,407
# ...

# %%
# DataFrame.transpose 과 DataFrame.set_index 을 사용하여 1행값을 열의 이름으로 변경하기

# %%
df4=df4.T.set_index(0).T.reset_index(drop=True).rename_axis(columns=None)

# %%
df4
# Out:
#    행정구역별(1) 행정구역별(2) 남녀성비<br>(A÷B×100) 남자인구수<br>(A) 여자인구수<br>(B)  \
# 0     서울특별시       소계              96.1    4,830,206    5,027,220
# 1       NaN      종로구              96.4       75,967       78,803
# 2       NaN       중구              98.1       62,253       63,456
# 3       NaN      용산구              93.7      110,878      118,283
# 4       NaN      성동구              97.4      150,368      154,440
# 5       NaN      광진구              95.2      174,414      183,289
# 6       NaN     동대문구             100.0      175,324      175,323
# 7       NaN      중랑구              99.2      203,325      204,901
# 8       NaN      성북구              95.2      216,556      227,499
# 9       NaN      강북구              96.0      158,918      165,561
# 10      NaN      도봉구              96.2      168,759      175,407
# 11      NaN      노원구              94.6      269,508      284,895
# 12      NaN      은평구              94.4      236,353      250,441
# ...

# %%
df4=df4.drop(columns=['행정구역별(1)'], axis=1)

# %%
# df4.set_index(["행정구역별(2)"],inplace=False)

# 이거치고 나중에 멀티 인덱스 코드를 모르겟음..ㅡㅡ
#reset이 안됨

# %%
df4.columns=["지역구","2017_남녀성비","2017_남자인구수","2017_여자인구수","2018_남녀성비","2018_남자인구수","2018_여자인구수","2019_남녀성비","2019_남자인구수","2019_여자인구수"]

# %%
df4
# Out:
#      지역구 2017_남녀성비 2017_남자인구수 2017_여자인구수 2018_남녀성비 2018_남자인구수 2018_여자인구수  \
# 0     소계      96.1  4,830,206  5,027,220      95.6  4,773,899  4,991,724
# 1    종로구      96.4     75,967     78,803      95.6     74,825     78,240
# 2     중구      98.1     62,253     63,456      97.1     61,947     63,778
# 3    용산구      93.7    110,878    118,283      93.5    110,640    118,359
# 4    성동구      97.4    150,368    154,440      96.5    151,359    156,862
# 5    광진구      95.2    174,414    183,289      94.5    172,794    182,765
# 6   동대문구     100.0    175,324    175,323      99.5    173,567    174,485
# 7    중랑구      99.2    203,325    204,901      98.8    200,419    202,790
# 8    성북구      95.2    216,556    227,499      94.6    211,904    223,964
# 9    강북구      96.0    158,918    165,561      95.7    156,071    163,093
# 10   도봉구      96.2    168,759    175,407      95.9    166,160    173,253
# 11   노원구      94.6    269,508    284,895      94.3    263,919    279,833
# ...

# %%
df_2017= df4.iloc[:,0:4]

# %%
df_2017
# Out:
#      지역구 2017_남녀성비 2017_남자인구수 2017_여자인구수
# 0     소계      96.1  4,830,206  5,027,220
# 1    종로구      96.4     75,967     78,803
# 2     중구      98.1     62,253     63,456
# 3    용산구      93.7    110,878    118,283
# 4    성동구      97.4    150,368    154,440
# 5    광진구      95.2    174,414    183,289
# 6   동대문구     100.0    175,324    175,323
# 7    중랑구      99.2    203,325    204,901
# 8    성북구      95.2    216,556    227,499
# 9    강북구      96.0    158,918    165,561
# 10   도봉구      96.2    168,759    175,407
# 11   노원구      94.6    269,508    284,895
# 12   은평구      94.4    236,353    250,441
# 13  서대문구      93.5    151,144    161,656
# 14   마포구      91.3    178,939    195,976
# 15   양천구      97.4    232,518    238,636
# 16   강서구      94.9    292,989    308,702
# 17   구로구      98.7    204,003    206,739
# 18   금천구     103.3    119,497    115,657
# 19  영등포구      99.7    183,975    184,575
# 20   동작구      95.2    193,255    202,962
# 21   관악구     101.6    253,661    249,636
# ...

# %%
df_2017=df_2017.astype({"2017_남녀성비":np.float})
# Out:
# <ipython-input-33-1f1ce8410c23>:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df_2017=df_2017.astype({"2017_남녀성비":np.float})

# %%
df_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   지역구         26 non-null     object
#  1   2017_남녀성비   26 non-null     float64
#  2   2017_남자인구수  26 non-null     object
#  3   2017_여자인구수  26 non-null     object
# dtypes: float64(1), object(3)
# memory usage: 960.0+ bytes

# %%
df_2017
# Out:
#      지역구  2017_남녀성비 2017_남자인구수 2017_여자인구수
# 0     소계       96.1  4,830,206  5,027,220
# 1    종로구       96.4     75,967     78,803
# 2     중구       98.1     62,253     63,456
# 3    용산구       93.7    110,878    118,283
# 4    성동구       97.4    150,368    154,440
# 5    광진구       95.2    174,414    183,289
# 6   동대문구      100.0    175,324    175,323
# 7    중랑구       99.2    203,325    204,901
# 8    성북구       95.2    216,556    227,499
# 9    강북구       96.0    158,918    165,561
# 10   도봉구       96.2    168,759    175,407
# 11   노원구       94.6    269,508    284,895
# 12   은평구       94.4    236,353    250,441
# 13  서대문구       93.5    151,144    161,656
# 14   마포구       91.3    178,939    195,976
# 15   양천구       97.4    232,518    238,636
# 16   강서구       94.9    292,989    308,702
# 17   구로구       98.7    204,003    206,739
# 18   금천구      103.3    119,497    115,657
# 19  영등포구       99.7    183,975    184,575
# 20   동작구       95.2    193,255    202,962
# ...

# %%
def func(x) :
    if x >=0  :
        return 2017
    else :
        return "none"
df_2017["년도"] = df_2017["2017_남녀성비"].apply(lambda x : func(x))

# %%
df_2017.columns=["지역구","남녀성비","남자인구수","여자인구수","년도"]

# %%
df_2017
# Out:
#      지역구   남녀성비      남자인구수      여자인구수    년도
# 0     소계   96.1  4,830,206  5,027,220  2017
# 1    종로구   96.4     75,967     78,803  2017
# 2     중구   98.1     62,253     63,456  2017
# 3    용산구   93.7    110,878    118,283  2017
# 4    성동구   97.4    150,368    154,440  2017
# 5    광진구   95.2    174,414    183,289  2017
# 6   동대문구  100.0    175,324    175,323  2017
# 7    중랑구   99.2    203,325    204,901  2017
# 8    성북구   95.2    216,556    227,499  2017
# 9    강북구   96.0    158,918    165,561  2017
# 10   도봉구   96.2    168,759    175,407  2017
# 11   노원구   94.6    269,508    284,895  2017
# 12   은평구   94.4    236,353    250,441  2017
# 13  서대문구   93.5    151,144    161,656  2017
# 14   마포구   91.3    178,939    195,976  2017
# 15   양천구   97.4    232,518    238,636  2017
# 16   강서구   94.9    292,989    308,702  2017
# 17   구로구   98.7    204,003    206,739  2017
# 18   금천구  103.3    119,497    115,657  2017
# 19  영등포구   99.7    183,975    184,575  2017
# ...

# %%
#2018

# %%
df4
# Out:
#      지역구 2017_남녀성비 2017_남자인구수 2017_여자인구수 2018_남녀성비 2018_남자인구수 2018_여자인구수  \
# 0     소계      96.1  4,830,206  5,027,220      95.6  4,773,899  4,991,724
# 1    종로구      96.4     75,967     78,803      95.6     74,825     78,240
# 2     중구      98.1     62,253     63,456      97.1     61,947     63,778
# 3    용산구      93.7    110,878    118,283      93.5    110,640    118,359
# 4    성동구      97.4    150,368    154,440      96.5    151,359    156,862
# 5    광진구      95.2    174,414    183,289      94.5    172,794    182,765
# 6   동대문구     100.0    175,324    175,323      99.5    173,567    174,485
# 7    중랑구      99.2    203,325    204,901      98.8    200,419    202,790
# 8    성북구      95.2    216,556    227,499      94.6    211,904    223,964
# 9    강북구      96.0    158,918    165,561      95.7    156,071    163,093
# 10   도봉구      96.2    168,759    175,407      95.9    166,160    173,253
# 11   노원구      94.6    269,508    284,895      94.3    263,919    279,833
# ...

# %%
df_2018= df4[['지역구','2018_남녀성비','2018_남자인구수','2018_여자인구수']]

# %%
df_2018
# Out:
#      지역구 2018_남녀성비 2018_남자인구수 2018_여자인구수
# 0     소계      95.6  4,773,899  4,991,724
# 1    종로구      95.6     74,825     78,240
# 2     중구      97.1     61,947     63,778
# 3    용산구      93.5    110,640    118,359
# 4    성동구      96.5    151,359    156,862
# 5    광진구      94.5    172,794    182,765
# 6   동대문구      99.5    173,567    174,485
# 7    중랑구      98.8    200,419    202,790
# 8    성북구      94.6    211,904    223,964
# 9    강북구      95.7    156,071    163,093
# 10   도봉구      95.9    166,160    173,253
# 11   노원구      94.3    263,919    279,833
# 12   은평구      93.7    233,702    249,495
# 13  서대문구      93.0    149,569    160,744
# 14   마포구      90.6    178,240    196,837
# 15   양천구      97.1    228,634    235,551
# 16   강서구      94.5    290,079    306,870
# 17   구로구      98.2    200,417    204,080
# 18   금천구     103.4    118,915    115,002
# 19  영등포구      99.3    183,224    184,554
# 20   동작구      94.5    192,533    203,670
# 21   관악구     100.9    252,160    249,797
# ...

# %%
df_2018=df_2018.astype({"2018_남녀성비":np.float})
# Out:
# <ipython-input-43-b55e24783f0d>:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df_2018=df_2018.astype({"2018_남녀성비":np.float})

# %%
def func(x) :
    if x >=0  :
        return 2018
    else :
        return "none"
df_2018["년도"] = df_2018["2018_남녀성비"].apply(lambda x : func(x))

# %%
df_2018.columns=["지역구","남녀성비","남자인구수","여자인구수","년도"]

# %%
df_2018
# Out:
#      지역구   남녀성비      남자인구수      여자인구수    년도
# 0     소계   95.6  4,773,899  4,991,724  2018
# 1    종로구   95.6     74,825     78,240  2018
# 2     중구   97.1     61,947     63,778  2018
# 3    용산구   93.5    110,640    118,359  2018
# 4    성동구   96.5    151,359    156,862  2018
# 5    광진구   94.5    172,794    182,765  2018
# 6   동대문구   99.5    173,567    174,485  2018
# 7    중랑구   98.8    200,419    202,790  2018
# 8    성북구   94.6    211,904    223,964  2018
# 9    강북구   95.7    156,071    163,093  2018
# 10   도봉구   95.9    166,160    173,253  2018
# 11   노원구   94.3    263,919    279,833  2018
# 12   은평구   93.7    233,702    249,495  2018
# 13  서대문구   93.0    149,569    160,744  2018
# 14   마포구   90.6    178,240    196,837  2018
# 15   양천구   97.1    228,634    235,551  2018
# 16   강서구   94.5    290,079    306,870  2018
# 17   구로구   98.2    200,417    204,080  2018
# 18   금천구  103.4    118,915    115,002  2018
# 19  영등포구   99.3    183,224    184,554  2018
# ...

# %%
#2019

# %%
df4
# Out:
#      지역구 2017_남녀성비 2017_남자인구수 2017_여자인구수 2018_남녀성비 2018_남자인구수 2018_여자인구수  \
# 0     소계      96.1  4,830,206  5,027,220      95.6  4,773,899  4,991,724
# 1    종로구      96.4     75,967     78,803      95.6     74,825     78,240
# 2     중구      98.1     62,253     63,456      97.1     61,947     63,778
# 3    용산구      93.7    110,878    118,283      93.5    110,640    118,359
# 4    성동구      97.4    150,368    154,440      96.5    151,359    156,862
# 5    광진구      95.2    174,414    183,289      94.5    172,794    182,765
# 6   동대문구     100.0    175,324    175,323      99.5    173,567    174,485
# 7    중랑구      99.2    203,325    204,901      98.8    200,419    202,790
# 8    성북구      95.2    216,556    227,499      94.6    211,904    223,964
# 9    강북구      96.0    158,918    165,561      95.7    156,071    163,093
# 10   도봉구      96.2    168,759    175,407      95.9    166,160    173,253
# 11   노원구      94.6    269,508    284,895      94.3    263,919    279,833
# ...

# %%
df_2019= df4[['지역구','2019_남녀성비','2019_남자인구수','2019_여자인구수']]

# %%
df_2019
# Out:
#      지역구 2019_남녀성비 2019_남자인구수 2019_여자인구수
# 0     소계      95.2  4,744,059  4,985,048
# 1    종로구      95.1     73,746     77,544
# 2     중구      96.3     61,910     64,261
# 3    용산구      93.3    110,356    118,314
# 4    성동구      95.9    147,273    153,616
# 5    광진구      94.0    170,262    181,088
# 6   동대문구      98.9    172,113    174,081
# 7    중랑구      98.5    196,959    200,056
# 8    성북구      94.0    214,437    228,213
# 9    강북구      95.3    153,235    160,719
# 10   도봉구      95.7    163,051    170,311
# 11   노원구      93.8    257,923    274,982
# 12   은평구      93.2    231,528    248,504
# 13  서대문구      92.5    148,663    160,734
# 14   마포구      89.7    176,891    197,144
# 15   양천구      96.7    225,186    232,979
# 16   강서구      93.9    286,563    305,233
# 17   구로구      97.7    200,987    205,677
# 18   금천구     103.1    118,209    114,601
# 19  영등포구      98.5    182,438    185,240
# 20   동작구      94.1    191,976    203,987
# 21   관악구     100.8    251,009    249,085
# ...

# %%
df_2019=df_2019.astype({"2019_남녀성비":np.float})
# Out:
# <ipython-input-51-c74f0182b3d7>:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df_2019=df_2019.astype({"2019_남녀성비":np.float})

# %%
def func(x) :
    if x >=0  :
        return 2019
    else :
        return "none"
df_2019["년도"] = df_2019["2019_남녀성비"].apply(lambda x : func(x))

# %%
df_2019.columns=["지역구","남녀성비","남자인구수","여자인구수","년도"]

# %%
df_2019
# Out:
#      지역구   남녀성비      남자인구수      여자인구수    년도
# 0     소계   95.2  4,744,059  4,985,048  2019
# 1    종로구   95.1     73,746     77,544  2019
# 2     중구   96.3     61,910     64,261  2019
# 3    용산구   93.3    110,356    118,314  2019
# 4    성동구   95.9    147,273    153,616  2019
# 5    광진구   94.0    170,262    181,088  2019
# 6   동대문구   98.9    172,113    174,081  2019
# 7    중랑구   98.5    196,959    200,056  2019
# 8    성북구   94.0    214,437    228,213  2019
# 9    강북구   95.3    153,235    160,719  2019
# 10   도봉구   95.7    163,051    170,311  2019
# 11   노원구   93.8    257,923    274,982  2019
# 12   은평구   93.2    231,528    248,504  2019
# 13  서대문구   92.5    148,663    160,734  2019
# 14   마포구   89.7    176,891    197,144  2019
# 15   양천구   96.7    225,186    232,979  2019
# 16   강서구   93.9    286,563    305,233  2019
# 17   구로구   97.7    200,987    205,677  2019
# 18   금천구  103.1    118,209    114,601  2019
# 19  영등포구   98.5    182,438    185,240  2019
# ...

# %%
df_year= pd.concat([df_2017,df_2018,df_2019])

# %%
df_year
# Out:
#     지역구   남녀성비      남자인구수      여자인구수    년도
# 0    소계   96.1  4,830,206  5,027,220  2017
# 1   종로구   96.4     75,967     78,803  2017
# 2    중구   98.1     62,253     63,456  2017
# 3   용산구   93.7    110,878    118,283  2017
# 4   성동구   97.4    150,368    154,440  2017
# ..  ...    ...        ...        ...   ...
# 21  관악구  100.8    251,009    249,085  2019
# 22  서초구   91.7    206,039    224,787  2019
# 23  강남구   91.7    260,806    284,363  2019
# 24  송파구   93.8    327,164    348,797  2019
# 25  강동구   97.6    215,335    220,732  2019
#
# [78 rows x 5 columns]

# %%
df_year.to_csv('df_year.csv')

# %%
df_final=df_year.set_index(["년도","지역구"],inplace=False)

# %%
df_final
# Out:
#            남녀성비      남자인구수      여자인구수
# 년도   지역구
# 2017 소계    96.1  4,830,206  5,027,220
#      종로구   96.4     75,967     78,803
#      중구    98.1     62,253     63,456
#      용산구   93.7    110,878    118,283
#      성동구   97.4    150,368    154,440
# ...         ...        ...        ...
# 2019 관악구  100.8    251,009    249,085
#      서초구   91.7    206,039    224,787
#      강남구   91.7    260,806    284,363
#      송파구   93.8    327,164    348,797
#      강동구   97.6    215,335    220,732
#
# [78 rows x 3 columns]

# %%
df_final.to_csv('df_final.csv')
