# %% [markdown]
# ### 이용 빈도가 높은 웹사이트 순위를 제공하는 사이트 크롤링
#
# - 크롤링 사이트
#     -https://www.alexa.com/topsites/countries/KR

# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
url="https://www.alexa.com/topsites/countries/KR"
    
html_website_ranking=requests.get(url).text
# html_website_ranking[:2000] 잘 넘어오는지 임의로 확인하기 위해서.
# 웬만한 사이트는 get 방식으로 처리가능.post나 보안형태는 적은편

# %%
soup_website_ranking=BeautifulSoup(html_website_ranking,"html.parser") #파서기를 lxml로 사용해도됨.오히려 이게 더 활용이 많은편

soup_website_ranking
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="origin-when-cross-origin" name="referer"/>
# <!-- Google Tag Manager -->
# <script>
#   dataLayer = window.dataLayer || [];
#   dataLayer.push({
#     "lifecycle_stage": "prospect",
#   	"logged-in":  false,
#     "customer": {
#
#       "status": "prospect",
#       "highest_subscription": false
#     }
#   });
#   </script>
# <!-- Page hiding snippet  -->
# <style>.async-hide { opacity: 0 !important} </style>
# <script>(function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
#   h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
#   (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
#   })(window,document.documentElement,'async-hide','dataLayer',4000,
#   {'GTM-TKWQ4WC':true});</script>
# <!-- Modified Analytics tracking code with Optimize plugin -->
# <script>
#       (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# ...

# %%
# p태그의 요소 안에서 a태그의 요소를 찾음

website_ranking=soup_website_ranking.select("p a")
                                           
website_ranking[0:6] # 첫번째 a태그에 순위와 상관없는 다른 자료가 들어있음
# Out:
# [<a href="https://support.alexa.com/hc/en-us/articles/200444340" target="_blank">this explanation</a>,
#  <a href="/siteinfo/google.com">Google.com</a>,
#  <a href="/siteinfo/naver.com">Naver.com</a>,
#  <a href="/siteinfo/youtube.com">Youtube.com</a>,
#  <a href="/siteinfo/daum.net">Daum.net</a>,
#  <a href="/siteinfo/tistory.com">Tistory.com</a>]

# %%
print(type(website_ranking[0]))
print(website_ranking[0].text) # 태그 내부의 text를 저장하고 있는 속성
print(website_ranking[0].get_text()) # 태그 내부의 text를 반환하는 함수
# Out:
# <class 'bs4.element.Tag'>
# this explanation
# this explanation

# %%
web_ranking_domain = []
for website_ranking_element in website_ranking:
    web_ranking_domain.append(website_ranking_element.get_text())
web_ranking_domain[:6]
# 아래와 동일
# Out:
# ['this explanation',
#  'Google.com',
#  'Naver.com',
#  'Youtube.com',
#  'Daum.net',
#  'Tistory.com']

# %%
# 모든 랭킹을 가져와서 리스트에 담기
website_ranking_domain= [website_ranking_element.get_text() for website_ranking_element in website_ranking]
print(website_ranking_domain[0:6])
print(len(website_ranking_domain))
# Out:
# ['this explanation', 'Google.com', 'Naver.com', 'Youtube.com', 'Daum.net', 'Tistory.com']
# 51

# %%
# 순위와 상관없는 첫번째 요소 제거
# website_ranking_domain.pop(0)  #'this explanation' 제거
print(website_ranking_domain[0:6])
# Out:
# ['Google.com', 'Naver.com', 'Youtube.com', 'Daum.net', 'Tistory.com', 'Kakao.com']

# %%
print(len(website_ranking_domain))
# Out:
# 50

# %%
# 전체 data 출력 후 확인
print("[Top site in south korea]")
for k in range(len(website_ranking_domain)):
    print("{0} : {1}".format(k+1,website_ranking_domain[k]))
# Out:
# [Top site in south korea]
# 1 : Google.com
# 2 : Naver.com
# 3 : Youtube.com
# 4 : Daum.net
# 5 : Tistory.com
# 6 : Kakao.com
# 7 : Tmall.com
# 8 : Google.co.kr
# 9 : Amazon.com
# 10 : Coupang.com
# 11 : Netflix.com
# 12 : Facebook.com
# 13 : Sohu.com
# 14 : Namu.wiki
# 15 : Qq.com
# 16 : Wikipedia.org
# 17 : Taobao.com
# 18 : 360.cn
# 19 : Jd.com
# 20 : Microsoft.com
# 21 : Baidu.com
# 22 : Instagram.com
# 23 : Dcinside.com
# 24 : Yahoo.com
# 25 : Adobe.com
# 26 : Twitch.tv
# 27 : Zoom.us
# 28 : 11st.co.kr
# 29 : Nate.com
# 30 : Donga.com
# 31 : Office.com
# 32 : Danawa.com
# 33 : Gmarket.co.kr
# 34 : Weibo.com
# 35 : Apple.com
# 36 : Fmkorea.com
# 37 : Sina.com.cn
# 38 : Chosun.com
# 39 : Ebay.com
# 40 : Saramin.co.kr
# 41 : Inven.co.kr
# 42 : Afreecatv.com
# 43 : Dropbox.com
# 44 : Aliexpress.com
# 45 : Bing.com
# 46 : Auction.co.kr
# 47 : Nicovideo.jp
# 48 : Jobkorea.co.kr
# 49 : Yahoo.co.jp
# 50 : Stackoverflow.com

# %%
import pandas as pd

# %%
website_ranking_dict={"website":website_ranking_domain }

df=pd.DataFrame(website_ranking_dict,columns=["website"], index=range(1,len(website_ranking_domain)+1))
df
# Out:
#               website
# 1          Google.com
# 2           Naver.com
# 3         Youtube.com
# 4            Daum.net
# 5         Tistory.com
# 6           Kakao.com
# 7           Tmall.com
# 8        Google.co.kr
# 9          Amazon.com
# 10        Coupang.com
# 11        Netflix.com
# 12       Facebook.com
# 13           Sohu.com
# 14          Namu.wiki
# 15             Qq.com
# 16      Wikipedia.org
# 17         Taobao.com
# 18             360.cn
# 19             Jd.com
# 20      Microsoft.com
# 21          Baidu.com
# 22      Instagram.com
# 23       Dcinside.com
# 24          Yahoo.com
# 25          Adobe.com
# 26          Twitch.tv
# 27            Zoom.us
# 28         11st.co.kr
# 29           Nate.com
# 30          Donga.com
# 31         Office.com
# 32         Danawa.com
# 33      Gmarket.co.kr
# 34          Weibo.com
# 35          Apple.com
# 36        Fmkorea.com
# 37        Sina.com.cn
# 38         Chosun.com
# 39           Ebay.com
# 40      Saramin.co.kr
# ...

# %%
# 연습문제: 위 df에 각 사이트의 정보를 제공하는 url까지 추출해서 컬럼으로 추구하시오~!!!!!!!!!!!!!!!

# %%
# 모든 랭킹을 가져와서 리스트에 담기
website_ranking_url= [website_ranking_element.get_text() for website_ranking_element in website_ranking]
print(website_ranking_domain[0:6])
print(len(website_ranking_domain))
