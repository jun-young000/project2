# %%
#동적 생성되는 data 크롤링
#Selenium 모듈 사용
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
from selenium import webdriver

# %% [markdown]
# #### selenium 패키지 모듈 이용한 자동 크롤링
# - webdriver라는 API를 통해 운영체제에 설치된 웹 브라우저를 제어하는 함수를 포함한 패키지
# - 써드파티라이브러리이기 때문에 설치 해 줘야 함
# - prompt 에서 설치
#     - pip install selenium

# %%
# 웹브라우져마다 웹드라이버를 제공하는 유무가 다름..크롬은 준다~!!

# %% [markdown]
# #### 크롬 드라이버 다운로드
# - https://chromedriver.chromium.org/downloads
#
# #### 크롬 정보 확인
# - 메뉴 - 도움말 - 크롬정보

# %%
#크롬 드라이버를 통한 네이버 접속
from selenium.webdriver.chrome.options import Options 
# from selenium.webdriver.chrome.options import Options

# %%
options = Options() 
options.binary_location= 'C:/Program Files (x86)/Google/Chrome/Application/chrome.exe' 
driver = webdriver.Chrome(".\driver\chromedriver",chrome_options = options)
driver.get("https://news.naver.com")
# Out:
# <ipython-input-13-f7a8825726e8>:3: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(".\driver\chromedriver",chrome_options = options)

# %%
# webdriver 객체 생성
driver =webdriver.Chrome(".\driver\chromedriver")

# %%
# 페이지 접근
url ='https://nid.naver.com/nidlogin.login' 
driver.get(url)

# %%
# 화면캡쳐


driver.save_screenshot('./crawl_data/sshot.png')
# Out:
# True

# %% [markdown]
# ---------------------여기부터는 맥 설정~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ### #### 맥은 터미널에서 크롬드라이버 다운 받은 경로로 이동하여 입력 (확인되지 않은 개발자의 프로그램 열기)
#
# ```
# $ sudo mv chromedriver /usr/local/bin
# $ sudo xattr -d com.apple.quarantine /usr/local/bin/chromedriver
# ```
# - 이후 주피터랩 재실행

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 크롬 드라이버를 통한 네이버 접속
#
#
# - from selenium.webdriver.chrome.options import Options
# - #from selenium import webdriver
# - options = Options()
# - options.binary_location= '/Applications/Google Chrome.app/Contents/MacOS/Google Chrome' # 맥의 크롬 경로
# - driver = webdriver.Chrome(executable_path='chromedriver',chrome_options = options)
# - url = "https://news.naver.com"
# - driver.get(url)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ------------------------ 맥설정 완료

# %% [markdown]
# #### 셀레니움을 이용한 동적 크롤링 순서
# 1. webdriver 객체 생성
#     - webdriver.브라우저명(웹드라이버경로/ path)
#
# 2. get(url) 메서드 이용해서 사이트에 문서를 요청 후 응답 반환
# 3. 접근한 페이지 소스코드를 추출
#     - driver.page_souce
# 4. 소스코드를 파서기에 적용 시켜서 추출

# %% [markdown]
# #### 동적 로그인 진행
# - 프로그램코드를 통해서 자동 로그인되게 브라우저를 제어

# %%
# webdriver 객체 생성
driver =webdriver.Chrome(".\driver\chromedriver")
# 페이지 접근
url ='https://nid.naver.com/nidlogin.login' 
driver.get(url)

# %%
# id 값을 전달
# 1. id를 입력할 element(input tag)를 찾아야 함- input type="text"  id="id"
id_elem=driver.find_element_by_id("id")

# 2. 미리 입력되어있는 값이 잇을수도 있으므로 지우기
id_elem.clear()   # 아이디값 지우기

# 3. send_keys() 함수를 이용해서 element 에 값을 전달
id_elem.send_keys("taropoint1")  #입력할 아이디 입력
#참고로 session이 종종 끊기는 경우가 생긴다.그러면 걍 웹드라이버접근부터 다시하삼

# %%
# password 값을 전달

# # 1. password를 입력할 element(input tag)를 찾아야 함- input type="text"  id="pw"
pw_elem=driver.find_element_by_id("pw")

# 2. 미리 입력되어있는 값이 잇을수도 있으므로 지우기
pw_elem.clear()   # 아이디값 지우기


# 3. send_keys() 함수를 이용해서 element 에 값을 전달
pw_elem.send_keys("sosabul0313")  #입력할 아이디 입력
#참고로 session이 종종 끊기는 경우가 생긴다.그러면 걍 웹드라이버접근부터 다시하삼

# %%
# 로그인 버튼 클릭
# 개발자 코드에서 copy후 xpath 찾기함
xpath='//*[@id="log.login"]'

driver.find_element_by_xpath(xpath).click()


# 여기까지 완료되면 자동입력 방지 문자를 입력하는 기능이 나타남

# %% [markdown]
# ![image.png](attachment:image.png)
# # 자동입력으로 인식함

# %%
# 자동입력방지 버튼이 나오는 이유
# 키보드 입력인지 자동입력인지 인식함.즉 위에서는 send_keys("어쩌구") 부분때문에 일어나게 된다.

# %%
## 자동입력 방지 문자를 우회하기 위해 브라우저 종료 후
## send_key( ) 함수 대신에 id/pass 값을  input 박스에 직접 value로 대입하는 스크립트 코드 작성후 실행

# %%
id_input="taropoint1"
pw_input="sosabul0313!!"
"document.getElementsByName('id')[0].value='"+id_input+"'"

# 자바 스크립트 코드(document.getElementsByName)를 활용한다
# Out:
# "document.getElementsByName('id')[0].value='taropoint1'"

# %%
driver = webdriver.Chrome('./driver/chromedriver')
url ='https://nid.naver.com/nidlogin.login' 
driver.get(url)

# %% [markdown]
# ### webdriver 통해 script 코드 직접 실행
# - driver.execute_script() 함수 - driver로 script 코드를 직접 실행

# %%
#id input tag의 value 값으로 id_input 변수 저장 값 대입 코드 실행

driver.execute_script("document.getElementsByName('id')[0].value='"+id_input+"'") 


#pw input tag의 value 값으로 pw_input 변수 저장 값 대입 코드 실행

driver.execute_script("document.getElementsByName('pw')[0].value='"+pw_input+"'")

# %%
# 로그인 버튼 클릭
# 개발자 코드에서 copy후 xpath 찾기함
xpath='//*[@id="log.login"]'

driver.find_element_by_xpath(xpath).click()


# 여기까지 완료되면 자동입력 방지 문자를 입력하는 기능이 나타남

# %%
## 메일 페이지로 접근
driver.get("https://mail.naver.com")

# %%
## 코드추출

html =driver.page_source
soup=BeautifulSoup(html,"html.parser")

# %%
soup
# Out:
# <html lang="ko"><head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/css/mail2_le.min.210729.css" rel="stylesheet" type="text/css"/>
# <link href="/css/mail_skin.min.210729.css" rel="stylesheet" type="text/css"/>
# <link href="//ssl.pstatic.net" rel="dns-prefetch"/>
# <link href="//lcs.naver.com" rel="dns-prefetch"/>
# <link href="//cc.naver.com" rel="dns-prefetch"/>
# <link href="//static.nid.naver.com" rel="dns-prefetch"/>
# <link href="//phinf.pstatic.net" rel="dns-prefetch"/>
# <link href="/css/mail_me.min.210729.css" rel="stylesheet" type="text/css"/>
# <link href="/favicon.ico?2" rel="shortcut icon"/>
# <title>받은메일함(2) : 네이버 메일</title>
# <script type="text/javascript">
#
#
#
# 		var gnb_service = "mail";
# 		var gnb_logout = "http://www.naver.com";
# 		var gnb_template = "gnb_utf8";
# 		var gnb_brightness = 3;
# 		var gnb_item_hide_option = 8;
# 		var gnb_one_naver = 1;
#
#
# ...

# %%
### 메일 보낸이를 표현하는 div tag
 -`<div class="name _ccr(lst.from) ">` <b> `<span class="blind">보낸 이:</span>` </b> `<a title="&quot;네이버&quot; <webmaster@naver.com>" class="_c1(myContextMenu|showSenderContextLayer|list|2) _stopDefault" href="#">네이버</a></div>`
# Out:
#   File "<ipython-input-64-bb19753dc99a>", line 2
#     -`<div class="name _ccr(lst.from) ">` <b> `<span class="blind">보낸 이:</span>` </b> `<a title="&quot;네이버&quot; <webmaster@naver.com>" class="_c1(myContextMenu|showSenderContextLayer|list|2) _stopDefault" href="#">네이버</a></div>`
#     ^
# IndentationError: unexpected indent

# %%
raw_list = soup.find_all('div',{'class':"name _ccr(lst.from)"}) #from)공백" 인경우도 있으니 조정하면서..할것
raw_list
# Out:
# [<div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|94595) _stopDefault" href="#" title='"쿠팡" &lt;no_reply@e.coupang.com&gt;'>쿠팡</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|94594) _stopDefault" href="#" title='"사람인 | 추천" &lt;avatar_matching@mailinfo.saramin.co.kr&gt;'>사람인 | 추천</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|94589) _stopDefault" href="#" title='"인터넷보험가입센터" &lt;mail1@jwmaildove.co.kr&gt;'>인터넷보험가입센터</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|94588) _stopDefault" href="#" title='"쿠팡" &lt;no_reply@e.coupang.com&gt;'>쿠팡</a></div>,
# ...

# %%
raw_list
# Out:
# [<div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|94595) _stopDefault" href="#" title='"쿠팡" &lt;no_reply@e.coupang.com&gt;'>쿠팡</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|94594) _stopDefault" href="#" title='"사람인 | 추천" &lt;avatar_matching@mailinfo.saramin.co.kr&gt;'>사람인 | 추천</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|94589) _stopDefault" href="#" title='"인터넷보험가입센터" &lt;mail1@jwmaildove.co.kr&gt;'>인터넷보험가입센터</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|94588) _stopDefault" href="#" title='"쿠팡" &lt;no_reply@e.coupang.com&gt;'>쿠팡</a></div>,
# ...

# %%
send_list=[raw_list[n].find('a').get_text() for n in range(0,len(raw_list))]

# %%
send_list
# Out:
# ['쿠팡',
#  '사람인 | 추천',
#  '인터넷보험가입센터',
#  '쿠팡',
#  '사람인 | 매칭연구소',
#  'Facebook',
#  '잡코리아 | 스마트매..',
#  'Nomad Coders',
#  '네이버 시리즈',
#  'Facebook',
#  '캐치ㅣ주간채용',
#  'Facebook',
#  '사람인 | 매칭연구소',
#  '사람인 | 추천',
#  'Facebook']
