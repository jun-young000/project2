# %%
pip install pandas_visual_analysis
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
from pandas_visual_analysis import VisualAnalysis
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
import pyecharts

# %%
# 한글 폰트 적용
plt.rc('font', family='NanumBarunGothic') 
# 캔버스 사이즈 적용
plt.rcParams["figure.figsize"] = (12, 9)

# %%
# 리스타트

# %%
df = sns.load_dataset('mpg')
df.head(10)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
# 5  15.0          8         429.0       198.0    4341          10.0
# 6  14.0          8         454.0       220.0    4354           9.0
# 7  14.0          8         440.0       215.0    4312           8.5
# 8  14.0          8         455.0       225.0    4425          10.0
# 9  15.0          8         390.0       190.0    3850           8.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# ...

# %%
VisualAnalysis(df)

# %% [markdown]
# brush summary 기능 : Metric을 모든 분위수 기준으로 변경 가능
# histogram 기능 : normalize 가능
# scatter plot 기능 : x, y에 원하는 변수 선택 가능, size 매트릭에 원하는 변수 추가 가능

# %%
VisualAnalysis.widgets()
# Out:
# ['Scatter',
#  'ParallelCoordinates',
#  'BrushSummary',
#  'Histogram',
#  'ParallelCategories',
#  'BoxPlot']

# %% [markdown]
# 스캐터 플롯, Parallel coordinates(평행 좌표 시각화), 브러시 써머리(= 판다스 describe 출력 데이터와 유사), 히스토그램, Parallel categories(평행 좌표 범주형 시각화), 박스플롯 이렇게 6가지의 그래프를 사용할 수 있다.

# %%
VisualAnalysis(df,
    layout=[["Scatter", "ParallelCoordinates"],
            ["BoxPlot", 'Histogram']],
               row_height=[200, 200]   # 인터페이스 전체 넓이 및 높이 지정
)

# %% [markdown]
# Standard : 영역을 선택할 때마다 새롭게 영역이 잡힘
# Additive : 기존 선택 영역에서 데이터 포인트를 추가할 때 사용
# Subtractive : 기존 선택 영역에서 데이터 포인트를 제거할 때 사용

# %%
VisualAnalysis(df,
    layout=[["ParallelCoordinates"],
            ["ParallelCategories"]],
               row_height=[200, 300]
)

# %% [markdown]
# 세부적인 옵션 적용하기

# %%
VisualAnalysis(df, row_height=200, sample=0.5, seed=17, categorical_columns=['origin', 'name'],
              select_color='#880E4F', deselect_color='#8A8C93', alpha=0.75)

# %% [markdown]
# select_color, deselect_color : 데이터 영역 지정 시 선택된 컬러는 select_color로, 그 외의 영역은 deselect_color로 지정 가능
#
# sample, seed : 데이터 샘플링 비중 및 seed 지정 가능, 데이터셋이 클 경우 샘플링하여 시각화하면 좀 더 빠르게 할 수 있음
#
# categorical_columns : 범주형 변수를 따로 지정해줌, 복수인 경우 리스트 형태로 입력, 위젯에서 지정된 범주형 변수들을 알맞게 시각화해 줌
#
# alpha : 스케터 플롯처럼 밀도가 높은 데이터 영역에 투명도를 적용하면 더욱 상세하게 관찰 가능

# %%
value = pd.read_csv('price_crime.csv', encoding='utf-8')

# %%
value
# Out:
#     Unnamed: 0   지역구  공시지가 대비 5대범죄 발생         5대범죄         살인         강도  \
# 0            0   강남구           2018.0  7512.333333   7.333333  13.000000
# 1            1   강동구           2018.0  4064.666667   4.666667  10.666667
# 2            2   강북구           2018.0  3556.000000   7.333333   5.666667
# 3            3   강서구           2018.0  4896.000000  10.000000   4.333333
# 4            4   관악구           2018.0  5293.000000  10.000000   9.000000
# 5            5   광진구           2018.0  4190.666667   5.666667   7.000000
# 6            6   구로구           2018.0  4804.000000   8.333333   6.666667
# 7            7   금천구           2018.0  3221.000000   5.666667   7.333333
# 8            8   노원구           2018.0  4123.000000   4.333333   5.666667
# 9            9   도봉구           2018.0  2119.333333   1.000000   4.333333
# 10          10  동대문구           2018.0  3782.333333   6.333333   6.000000
# 11          11   동작구           2018.0  3276.666667   2.666667   5.000000
# ...

# %%
value.drop("Unnamed: 0", axis=1, inplace=True)

# %%
value.drop("공시지가 대비 5대범죄 발생", axis=1, inplace=True)

# %%
value.drop("랭크용", axis=1, inplace=True)

# %%
value
# Out:
#      지역구         5대범죄         살인         강도      강간강제추행           절도  \
# 0    강남구  7512.333333   7.333333  13.000000  624.333333  3034.666667
# 1    강동구  4064.666667   4.666667  10.666667  174.000000  1603.333333
# 2    강북구  3556.000000   7.333333   5.666667  190.666667  1118.333333
# 3    강서구  4896.000000  10.000000   4.333333  297.000000  1887.333333
# 4    관악구  5293.000000  10.000000   9.000000  379.666667  2071.333333
# 5    광진구  4190.666667   5.666667   7.000000  254.333333  1954.666667
# 6    구로구  4804.000000   8.333333   6.666667  268.000000  1786.000000
# 7    금천구  3221.000000   5.666667   7.333333  197.666667  1155.333333
# 8    노원구  4123.000000   4.333333   5.666667  186.000000  1486.000000
# 9    도봉구  2119.333333   1.000000   4.333333  102.333333   734.666667
# 10  동대문구  3782.333333   6.333333   6.000000  159.333333  1508.333333
# 11   동작구  3276.666667   2.666667   5.000000  311.666667  1235.000000
# 12   마포구  5097.333333   3.666667   5.333333  489.333333  2098.333333
# ...

# %%
VisualAnalysis(value )

# %%
sns.kdeplot(value ["평균지가"],value["5대범죄"],shade=True,color="#4E6BA6")
sns.rugplot(value ["평균지가"], color="b")
sns.rugplot(value ["5대범죄"], color="r", vertical=True);
# Out:
# C:\Users\ui\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# C:\Users\ui\anaconda3\lib\site-packages\seaborn\distributions.py:2065: FutureWarning:
#
# Using `vertical=True` to control the orientation of the plot  is deprecated. Instead, assign the data directly to `y`.
#
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 54217 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44512 missing from current font.
#
# ...

# %%
sns.jointplot(x=value["평균지가"],y=value["5대범죄"],kind="reg")
# Out:
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 54217 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44512 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 51648 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44032 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 45824 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 48276 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 51396 missing from current font.
# ...

# %%
sns.jointplot(x=value["평균지가"],y=value["살인"],kind="reg")
# Out:
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 54217 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44512 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 51648 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44032 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 49332 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 51064 missing from current font.
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 54217 missing from current font.
#
# ...

# %%
sns.jointplot(x=value["평균지가"],y=value["강도"],kind="reg")
# Out:
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 54217 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44512 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 51648 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44032 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44053 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 46020 missing from current font.
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 54217 missing from current font.
#
# ...

# %%
sns.jointplot(x=value["평균지가"],y=value["절도"],kind="reg")
# Out:
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 54217 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44512 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 51648 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44032 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 51208 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 46020 missing from current font.
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 54217 missing from current font.
#
# ...

# %%
sns.jointplot(x=value["평균지가"],y=value["강간강제추행"],kind="reg")
# Out:
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 54217 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44512 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 51648 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44032 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44053 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44036 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 51228 missing from current font.
# ...

# %%
sns.jointplot(x=value["평균지가"],y=value["폭력"],kind="reg")
# Out:
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 54217 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44512 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 51648 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44032 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 54253 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 47141 missing from current font.
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 54217 missing from current font.
#
# ...

# %%
sns.jointplot(x=value["평균지가"],y=value["5대범죄"],kind="reg")
# Out:
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 54217 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44512 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 51648 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44032 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 45824 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 48276 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 51396 missing from current font.
# ...

# %%
valu1 = pd.read_csv('price_crime_year.csv', encoding='utf-8')

# %%
valu1
# Out:
#     Unnamed: 0    기간   지역구    합계  살인  강도  강간강제추행    절도    폭력       평균지가  \
# 0            0  2017   강남구  7720   7  20     607  3130  3956  4840000.0
# 1            1  2017  영등포구  5969  15   5     455  2304  3190  3604000.0
# 2            2  2017   송파구  5576   6   1     288  2274  3007  1451000.0
# 3            3  2017   관악구  5525   8   7     379  1979  3152  2375300.0
# 4            4  2017   마포구  5278   3   8     500  2094  2673  1883200.0
# ..         ...   ...   ...   ...  ..  ..     ...   ...   ...        ...
# 70          70  2019   금천구  3105   6  10     153  1157  1779  2383360.0
# 71          71  2019  서대문구  2943   2   5     175  1226  1535  3577180.0
# 72          72  2019   성북구  2877   3   3     176  1082  1613  4271200.0
# 73          73  2019   성동구  2512   6   9     133   970  1394  7809400.0
# 74          74  2019   도봉구  2110   1   5      90   790  1224   830380.0
#
#           결과       랭크용
# 0   0.159504  0.159504
# 1   0.165622  0.165622
# 2   0.384287  0.384287
# ...

# %%
valu1.drop("Unnamed: 0", axis=1, inplace=True)

# %%
valu1.drop("결과", axis=1, inplace=True)

# %%
valu1
# Out:
#       기간   지역구    합계  살인  강도  강간강제추행    절도    폭력       평균지가       랭크용
# 0   2017   강남구  7720   7  20     607  3130  3956  4840000.0  0.159504
# 1   2017  영등포구  5969  15   5     455  2304  3190  3604000.0  0.165622
# 2   2017   송파구  5576   6   1     288  2274  3007  1451000.0  0.384287
# 3   2017   관악구  5525   8   7     379  1979  3152  2375300.0  0.232602
# 4   2017   마포구  5278   3   8     500  2094  2673  1883200.0  0.280268
# ..   ...   ...   ...  ..  ..     ...   ...   ...        ...       ...
# 70  2019   금천구  3105   6  10     153  1157  1779  2383360.0  0.130278
# 71  2019  서대문구  2943   2   5     175  1226  1535  3577180.0  0.082272
# 72  2019   성북구  2877   3   3     176  1082  1613  4271200.0  0.067358
# 73  2019   성동구  2512   6   9     133   970  1394  7809400.0  0.032166
# 74  2019   도봉구  2110   1   5      90   790  1224   830380.0  0.254101
#
# [75 rows x 10 columns]

# %%
VisualAnalysis(value ,
    layout=[["Scatter", "Scatter"],
            ["Scatter", 'Scatter']],
               row_height=[600, 600],alpha=0.75   # 인터페이스 전체 넓이 및 높이 지정
)

# %%
VisualAnalysis(value,
    layout=[["Scatter", "ParallelCoordinates"],
            ["BoxPlot", 'Histogram']],
               row_height=[400, 400]   # 인터페이스 전체 넓이 및 높이 지정
)
# 3년 평균

# %%
VisualAnalysis(valu1,
    layout=[["Scatter", "ParallelCoordinates"],
            ["BoxPlot", 'Histogram']],
               row_height=[400, 400]   # 인터페이스 전체 넓이 및 높이 지정
)  # 년마다 다르게

# %%
value
# Out:
#      지역구         5대범죄         살인         강도      강간강제추행           절도  \
# 0    강남구  7512.333333   7.333333  13.000000  624.333333  3034.666667
# 1    강동구  4064.666667   4.666667  10.666667  174.000000  1603.333333
# 2    강북구  3556.000000   7.333333   5.666667  190.666667  1118.333333
# 3    강서구  4896.000000  10.000000   4.333333  297.000000  1887.333333
# 4    관악구  5293.000000  10.000000   9.000000  379.666667  2071.333333
# 5    광진구  4190.666667   5.666667   7.000000  254.333333  1954.666667
# 6    구로구  4804.000000   8.333333   6.666667  268.000000  1786.000000
# 7    금천구  3221.000000   5.666667   7.333333  197.666667  1155.333333
# 8    노원구  4123.000000   4.333333   5.666667  186.000000  1486.000000
# 9    도봉구  2119.333333   1.000000   4.333333  102.333333   734.666667
# 10  동대문구  3782.333333   6.333333   6.000000  159.333333  1508.333333
# 11   동작구  3276.666667   2.666667   5.000000  311.666667  1235.000000
# 12   마포구  5097.333333   3.666667   5.333333  489.333333  2098.333333
# ...

# %%
sns.pairplot(value)
sns.set(font='Malgun Gothic', 
        rc={"axes.unicode_minus":False},
        style='darkgrid')
# Out:
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 45824 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 48276 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 51396 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 49332 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 51064 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 44053 missing from current font.
#
# C:\Users\ui\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 46020 missing from current font.
# ...

# %%
sns.pairplot(valu1 ,hue="기간")

# %%
sns.pairplot(valu1 ,hue="지역구")
# Out:
# C:\Users\ui\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning:
#
# Dataset has 0 variance; skipping density estimate.
