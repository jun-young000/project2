# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# 전체 코드 출력
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
# 한글 문제
# matplotlit의 기본 폰트에서 한글 지원되지 않기 때문에
# matplotlib의 폰트 변경 필요
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
crime_data = pd.read_excel('../[0]data/서울시_5대범죄_년도별.xls')
crime_data
# Out:
#       기간  자치구      합계   합계.1   살인 살인.1   강도 강도.1 강간강제추행 강간강제추행.1     절도  \
# 0     기간  자치구      발생     검거   발생   검거   발생   검거     발생       검거     발생
# 1   2017   합계  107835  79865  142  140  169  170   6963     6558  41162
# 2   2017  종로구    4057   4437    7    9   10   15    253     1412   1644
# 3   2017   중구    4184   2851    1    -    9    9    267      149   1846
# 4   2017  용산구    4060   2936    1    1    5    4    327      289   1346
# ..   ...  ...     ...    ...  ...  ...  ...  ...    ...      ...    ...
# 74  2019  관악구    5328   3810   13   10   10   11    408      335   2223
# 75  2019  서초구    5542   3750    5    5    7    5    616      412   2270
# 76  2019  강남구    7304   5069    5    3    5    6    666      562   2970
# 77  2019  송파구    5698   3799    7    8   10   10    273      230   2416
# 78  2019  강동구    4014   2955    6    5   15   14    180      155   1650
#
#      절도.1     폭력   폭력.1
# 0      검거     발생     검거
# 1   21421  59399  51576
# 2     905   2143   2096
# ...

# %%
crime_data_new= crime_data.iloc[:,4::2]
crime_data_new
# Out:
#      살인   강도 강간강제추행     절도     폭력
# 0    발생   발생     발생     발생     발생
# 1   142  169   6963  41162  59399
# 2     7   10    253   1644   2143
# 3     1    9    267   1846   2061
# 4     1    5    327   1346   2381
# ..  ...  ...    ...    ...    ...
# 74   13   10    408   2223   2674
# 75    5    7    616   2270   2644
# 76    5    5    666   2970   3658
# 77    7   10    273   2416   2992
# 78    6   15    180   1650   2163
#
# [79 rows x 5 columns]

# %%
crime_data_name = crime_data.iloc[:,0:2]
crime_data_name
# Out:
#       기간  자치구
# 0     기간  자치구
# 1   2017   합계
# 2   2017  종로구
# 3   2017   중구
# 4   2017  용산구
# ..   ...  ...
# 74  2019  관악구
# 75  2019  서초구
# 76  2019  강남구
# 77  2019  송파구
# 78  2019  강동구
#
# [79 rows x 2 columns]

# %%
crime_data = pd.concat([crime_data_name,crime_data_new],axis=1)
crime_data.head(30)
crime_data.tail(30)
# Out:
#       기간   자치구   살인   강도 강간강제추행     절도     폭력
# 0     기간   자치구   발생   발생     발생     발생     발생
# 1   2017    합계  142  169   6963  41162  59399
# 2   2017   종로구    7   10    253   1644   2143
# 3   2017    중구    1    9    267   1846   2061
# 4   2017   용산구    1    5    327   1346   2381
# 5   2017   성동구    1    3    132   1072   1559
# 6   2017   광진구    6   13    261   2220   2146
# 7   2017  동대문구   11    3    165   1547   2249
# 8   2017   중랑구    5    3    172   1533   2858
# 9   2017   성북구    7    8    173   1344   1902
# 10  2017   강북구    8    7    208   1014   2156
# 11  2017   도봉구    1    3    104    633   1258
# 12  2017   노원구    4    9    180   1538   2478
# 13  2017   은평구    6    4    230   1387   2256
# 14  2017  서대문구    4    1    202   1230   1676
# 15  2017   마포구    3    8    500   2094   2673
# 16  2017   양천구    3    3    138   1590   2148
# 17  2017   강서구   11    4    316   1888   2916
# 18  2017   구로구    7    8    328   1725   2827
# ...

# %%
 crime_data.drop(index=[0,1,27,53],inplace=True)

# %%
crime_data.head(30)
crime_data.tail(30)
# Out:
#       기간   자치구  살인  강도 강간강제추행    절도    폭력
# 2   2017   종로구   7  10    253  1644  2143
# 3   2017    중구   1   9    267  1846  2061
# 4   2017   용산구   1   5    327  1346  2381
# 5   2017   성동구   1   3    132  1072  1559
# 6   2017   광진구   6  13    261  2220  2146
# 7   2017  동대문구  11   3    165  1547  2249
# 8   2017   중랑구   5   3    172  1533  2858
# 9   2017   성북구   7   8    173  1344  1902
# 10  2017   강북구   8   7    208  1014  2156
# 11  2017   도봉구   1   3    104   633  1258
# 12  2017   노원구   4   9    180  1538  2478
# 13  2017   은평구   6   4    230  1387  2256
# 14  2017  서대문구   4   1    202  1230  1676
# 15  2017   마포구   3   8    500  2094  2673
# 16  2017   양천구   3   3    138  1590  2148
# 17  2017   강서구  11   4    316  1888  2916
# 18  2017   구로구   7   8    328  1725  2827
# 19  2017   금천구   5   5    240  1141  1874
# 20  2017  영등포구  15   5    455  2304  3190
# 21  2017   동작구   1   7    396  1226  1700
# 22  2017   관악구   8   7    379  1979  3152
# ...

# %%
 crime_data.rename(columns={ crime_data.columns[1]:"지역구"},inplace=True)

# %%
crime_data=crime_data.set_index(["기간","지역구"])

# %%
col=["살인","강도","강간강제추행","절도","폭력"]
crime_data["5대범죄"] = np.sum(crime_data[col],axis=1)

# %%
crime_data.head(25)
# Out:
#            살인  강도 강간강제추행    절도    폭력    5대범죄
# 기간   지역구
# 2017 종로구    7  10    253  1644  2143  4057.0
#      중구     1   9    267  1846  2061  4184.0
#      용산구    1   5    327  1346  2381  4060.0
#      성동구    1   3    132  1072  1559  2767.0
#      광진구    6  13    261  2220  2146  4646.0
#      동대문구  11   3    165  1547  2249  3975.0
#      중랑구    5   3    172  1533  2858  4571.0
#      성북구    7   8    173  1344  1902  3434.0
#      강북구    8   7    208  1014  2156  3393.0
#      도봉구    1   3    104   633  1258  1999.0
#      노원구    4   9    180  1538  2478  4209.0
#      은평구    6   4    230  1387  2256  3883.0
#      서대문구   4   1    202  1230  1676  3113.0
#      마포구    3   8    500  2094  2673  5278.0
#      양천구    3   3    138  1590  2148  3882.0
#      강서구   11   4    316  1888  2916  5135.0
#      구로구    7   8    328  1725  2827  4895.0
#      금천구    5   5    240  1141  1874  3265.0
#      영등포구  15   5    455  2304  3190  5969.0
#      동작구    1   7    396  1226  1700  3330.0
# ...

# %%
crime_data.head(5)
crime_data.tail(5)
# Out:
#          살인  강도 강간강제추행    절도    폭력    5대범죄
# 기간   지역구
# 2017 종로구  7  10    253  1644  2143  4057.0
#      중구   1   9    267  1846  2061  4184.0
#      용산구  1   5    327  1346  2381  4060.0
#      성동구  1   3    132  1072  1559  2767.0
#      광진구  6  13    261  2220  2146  4646.0
#           살인  강도 강간강제추행    절도    폭력    5대범죄
# 기간   지역구
# 2019 관악구  13  10    408  2223  2674  5328.0
#      서초구   5   7    616  2270  2644  5542.0
#      강남구   5   5    666  2970  3658  7304.0
#      송파구   7  10    273  2416  2992  5698.0
#      강동구   6  15    180  1650  2163  4014.0

# %%
crime_data.to_csv('../[0]data/서울시_5대범죄율_발생건수(결과).csv')
