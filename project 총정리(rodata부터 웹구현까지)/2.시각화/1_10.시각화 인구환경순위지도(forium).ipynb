# %%
import seaborn as sns
import pandas as pd
import folium
import json
from folium.features import DivIcon

# %%
total = pd.read_csv("인구환경순위.csv")

# %%
total
# Out:
#     Unnamed: 0   지역구  성비순위  1인가구순위  유동인구순위  외국인순위  인구밀도순위  인구환경순위
# 0            0   강남구    25       7      12     18      24      86
# 1            1   강동구    13      10       9     14      12      58
# 2            2   강북구     8      14      23     21      14      80
# 3            3   강서구    19      20      11     19      21      90
# 4            4   관악구    20      25      17      4      17      83
# 5            5   광진구    17      15      16      6       9      63
# 6            6   구로구    18       4      20      1      11      54
# 7            7   금천구     3       5      25      3       7      43
# 8            8   노원구    15      16       7     24      15      77
# 9            9   도봉구     1      21       4     25       1      52
# 10          10  동대문구     9      17      14     13       5      58
# 11          11   동작구     6      23       6      7       2      44
# 12          12   마포구    22      13      15     15      19      84
# 13          13  서대문구     4      22       3      8       6      43
# 14          14   서초구    21       6       8     16      23      74
# 15          15   성동구     2      19       2     11       4      38
# 16          16   성북구     5      24       1      5       8      43
# 17          17   송파구    24      12       5     17      16      74
# 18          18   양천구     7       9      13     20       3      52
# 19          19  영등포구    23       3      21      2      22      71
# 20          20   용산구    10       8      18      9      20      65
# 21          21   은평구    11      18      10     22      13      74
# 22          22   종로구    12       2      19     10      25      68
# 23          23    중구    14       1      22     12      18      67
# 24          24   중랑구    16      11      24     23      10      84

# %%
geo_path = ('./seoul_municipalities_geo_simple.json')

get_str = json.load(open(geo_path, encoding='utf-8'))

seoul_map = folium.Map(location = [37.5502, 126.982],zoom_start = 10.5)



folium.Choropleth(
    geo_data = get_str,
    data = total,
    columns = ['지역구', '인구환경순위'],
    fill_color='OrRd',
    key_on='properties.name',
    ).add_to(seoul_map)



text = '동작구'
circle_lat = 37.5092
circle_lon = 126.967


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)



text = '중구'
circle_lat = 37.5650
circle_lon = 126.999


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)



text = '중구'
circle_lat = 37.5650
circle_lon = 126.999


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)




text = '성동구'
circle_lat = 37.5600
circle_lon = 127.040


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)



text = '서초구'
circle_lat = 37.5000
circle_lon = 127.000


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)



text = '강남구'
circle_lat = 37.5100
circle_lon = 127.050


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)


text = '송파구'
circle_lat = 37.5100
circle_lon = 127.120


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)



text = '강동구'
circle_lat = 37.5600
circle_lon = 127.140


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)



text = '광진구'
circle_lat = 37.5600
circle_lon = 127.090


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)



text = '중랑구'
circle_lat = 37.6050
circle_lon = 127.090


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)



text = '노원구'
circle_lat = 37.6650
circle_lon = 127.075


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)



text = '도봉구'
circle_lat = 37.6750
circle_lon = 127.033


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)




text = '강북구'
circle_lat = 37.6650
circle_lon = 127.000


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)



text = '성북구'
circle_lat = 37.6100
circle_lon = 127.020


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)



text = '동대문구'
circle_lat = 37.5990
circle_lon = 127.060


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)



text = '종로구'
circle_lat = 37.6100
circle_lon = 126.970


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)



text = '은평구'
circle_lat = 37.6300
circle_lon = 126.930

folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)




text = '서대문구'
circle_lat = 37.5930
circle_lon = 126.940


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)



text = '마포구'
circle_lat = 37.5680
circle_lon = 126.910


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)

:


text = '강서구'
circle_lat = 37.5700
circle_lon = 126.830


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)



text = '양천구'
circle_lat = 37.5430
circle_lon = 126.872


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)




text = '영등포구'
circle_lat = 37.5350
circle_lon = 126.905


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)




text = '구로구'
circle_lat = 37.5080
circle_lon = 126.858


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)




text = '금천구'
circle_lat = 37.4750
circle_lon = 126.895


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)



text = '관악구'
circle_lat = 37.4800
circle_lon = 126.940


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)


text = '용산구'
circle_lat = 37.5450
circle_lon = 126.980


folium.map.Marker(
    [circle_lat, circle_lon],
    icon=DivIcon(
        icon_size=(10,6),
        icon_anchor=(0,0), 
        html='<div style="font-size: pt; font-weight:bold;">%s</div>' % text,
        )
    ).add_to(seoul_map)


seoul_map

seoul_map.save("./population.html")
